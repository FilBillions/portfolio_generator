# %%
from backtest_port import Backtest

# %%
test = Backtest()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  6 of 6 completed

# %%
test.return_data()
# Out:
# Price            Close                                                  \
# Ticker            AAPL       HOOD        MSFT         NFLX        NVDA
# Date
# 2000-01-03    0.841048        NaN   35.726719          NaN    0.089425
# 2000-01-04    0.770139        NaN   34.519848          NaN    0.087037
# 2000-01-05    0.781408        NaN   34.883835          NaN    0.084172
# 2000-01-06    0.713787        NaN   33.715298          NaN    0.078680
# 2000-01-07    0.747598        NaN   34.155903          NaN    0.079994
# ...                ...        ...         ...          ...         ...
# 2025-06-26  201.000000  84.519997  497.450012  1306.670044  155.020004
# 2025-06-27  201.080002  83.029999  495.940002  1323.119995  157.750000
# 2025-06-30  205.169998  93.629997  497.410004  1339.130005  157.990005
# 2025-07-01  207.820007  92.330002  492.049988  1293.599976  153.300003
# 2025-07-02  212.440002  97.980003  491.089996  1284.859985  157.250000
#
# ...
