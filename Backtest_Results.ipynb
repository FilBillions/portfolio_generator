# %%
from csv_functions import return_hist, sharpe_hist, bear_hist, bull_hist

# %%
import_csv='portfolio_backtest_results.csv'

# %%
return_hist(import_csv,buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1000
# --------------------------------------------------
# 90% Confidence Interval: (54.7604, 59.4262)
# 95% Confidence Interval: (54.3134, 59.8731)
# 98% Confidence Interval: (53.7938, 60.3927)
# 99% Confidence Interval: (53.7938, 60.3927)
# --------------------------------------------------
# Model Results:
# Model Mean: 57.09%
# Model Std: 44.85%
# --------------------------------------------------
# SPY Buy/Hold Results:
# SPY Buy/Hold Mean: 9.47%
# SPY Buy/Hold Std: 14.72%
# --------------------------------------------------

# %%
sharpe_hist(import_csv, buy_hold=False, spy=True)
# Out:
# --------------------------------------------------
# n = 1000
# --------------------------------------------------
# 90% Confidence Interval: (1.5712, 1.696)
# 95% Confidence Interval: (1.5592, 1.7079)
# 98% Confidence Interval: (1.5453, 1.7218)
# 99% Confidence Interval: (1.5453, 1.7218)
# --------------------------------------------------
# Model Sharpe:
# Model Mean: 1.6336
# Model Std: 1.1998
# --------------------------------------------------
# SPY Sharpe:
# SPY Mean: 0.9854
# SPY Std: 1.527
# --------------------------------------------------
